# %% [markdown]
# # <div style='padding:25px;background-color:maroon;color:white;border-radius:4px;font-size:100%;text-align: center'> Insurance Analytics and Prediction<br></div>

# %% [markdown]
# # <div style='padding:5px;background-color:maroon;color:white;border-radius:2px;font-size:100%;text-align: center'>Clustering Model Training<br></div>
# ### <span style="color:Khaki;">Problem Statement for Customer Segmentation (Clustering):
# <span style="color: Chartreuse;">   &#9784; &nbsp;</span> Utilize clustering algorithms to group customers based on their banking behaviors, transaction histories, and demographics. <br>
# - Apply clustering algorithms to group policyholders based on similar characteristics and behavior.
# - Identify customer segments with common insurance needs and preferences.
# - Tailor marketing strategies and product offerings to specific clusters, enhancing customer
# engagement and increasing cross-selling opportunities.
#
# ![Clustering](cluster.png)

# %% [markdown]
# ## <span style="color:Aqua;">Importing libraries from Python</span>

# %%
import pandas as pd
pd.options.display.max_columns = None
pd.set_option("display.precision", 4)
pd.set_option('display.float_format', '{:.4f}'.format)

import numpy as np

import seaborn as sns
sns.set_theme(context='notebook', style='white', palette='dark', font='sans-serif', font_scale=1, color_codes=True, rc=None)
sns.set_style({'axes.facecolor': 'white','axes.edgecolor': 'white'})

import matplotlib.pyplot as plt
plt.rcParams.update({
    'text.color': 'black',  # Change font color
    'axes.labelcolor': 'black',  # Change axis label color
    'xtick.color': 'black',  # Change x-tick color
    'ytick.color': 'black',  # Change y-tick color
    'font.weight': 'bold',  # Change font weight
    'axes.titleweight': 'bold',  # Change title weight
    'axes.labelweight': 'bold',# Change label weight
})


from sklearn.preprocessing import StandardScaler, RobustScaler,MinMaxScaler,LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.cluster import KMeans, DBSCAN
from kneed import KneeLocator
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.decomposition import PCA

import pickle
from scipy.stats import ttest_ind
from termcolor import colored
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4992/3335963896.py", line 1, in <module>
#     import pandas as pd
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 50, in <module>
#     from pandas.core import (
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/ops/__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/ops/array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/computation/expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/numexpr/__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4992/3335963896.py", line 1, in <module>
#     import pandas as pd
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %% [markdown]
# ## <span style="color:Aqua;">Reading model dataset:</span>

# %%
df = pd.read_feather('transfered_data.feather')
df.sample(3)
# Out:
#      months_as_customer policy_bind_date policy_state  policy_deductable  \
# 447                 352       2013-07-12           IL                500
# 987                 235       2013-05-01           IL               2000
# 243                 174       2005-10-14           IL               2000
#
#     insured_sex insured_education_level insured_occupation insured_hobbies  \
# 447        MALE               Associate       tech-support        exercise
# 987        MALE                      JD       craft-repair        yachting
# 243      FEMALE                 College       tech-support       paintball
#
#     insured_relationship incident_date             incident_type  \
# 447                 wife    2015-01-15  Single Vehicle Collision
# 987       other-relative    2015-01-13  Single Vehicle Collision
# 243            own-child    2015-02-06   Multi-vehicle Collision
#
#       collision_type incident_severity authorities_contacted incident_state  \
# 447  Front Collision      Minor Damage                  Fire             NC
# 987   Side Collision      Major Damage                 Other             NC
# 243   Rear Collision        Total Loss             Ambulance             NY
#
#     incident_city incident_hour_of_the_day number_of_vehicles_involved  \
# 447     Riverwood                       23                           1
# 987     Hillsdale                       10                           1
# 243     Riverwood                       21                           3
#
#     property_damage bodily_injuries witnesses police_report_available  \
# 447             YES               2         2                      NO
# 987             YES               0         3                      NO
# 243             YES               2         2                      NO
#
#      auto_make auto_year fraud_reported  age_boxcox  \
# 447  Chevrolet      2009              N      4.6282
# 987  Chevrolet      2012              Y      4.2193
# 243      Dodge      2012              N      4.1141
#
#      policy_annual_premium_boxcox  total_claim_amount_boxcox  \
# 447                     1798.8185                144732.4629
# 987                     1457.8329                125775.7745
# 243                     1282.2508                137177.6379
#
#      injury_claim_cube  property_claim_cube  vehicle_claim_boxcox
# 447              25408                19560           118098.2974
# 987                  0                    0            97099.3895
# 243              22336                22336           101759.4804

# %% [markdown]
# ## <span style="color:Aqua;">Variable Partitioning:</span>

# %%
ordinal = ['insured_education_level','incident_severity',]

nominal = ['policy_state','insured_sex','insured_occupation','insured_hobbies','insured_relationship','incident_type',
           'collision_type','authorities_contacted','incident_state','incident_city','property_damage',
           'police_report_available','auto_make','fraud_reported']

discrete = ['months_as_customer','incident_hour_of_the_day','number_of_vehicles_involved','auto_year'
            ,'witnesses','bodily_injuries']
continuous = [
    'age_boxcox','policy_annual_premium_boxcox','total_claim_amount_boxcox','injury_claim_cube',
    'property_claim_cube','vehicle_claim_boxcox','insurance_age','vehicle_age','auto_year','policy_deductable']

date = ['policy_bind_date','incident_date']

non_cont =[]

len(ordinal + nominal + discrete +continuous + date)
# Out:
# 34

# %%
df['insurance_age'] = pd.to_numeric((df.incident_date.dt.year - df.policy_bind_date.dt.year),errors='raise',downcast='integer')
df['vehicle_age'] = pd.to_numeric((df.incident_date.dt.year - df.auto_year.astype(int)),errors='raise',downcast='integer')

# %% [markdown]
# ## <span style="color:Aqua;">Selecting Features:</span>

# %% [markdown]
# ### <span style="color:Khaki;">Selecting features for modeling:
#
# Selecting features basedon the characteristics. Removing few features may the quality of clustering.

# %%
df.insurance_age.value_counts().index.tolist()
# Out:
# [24,
#  13,
#  23,
#  25,
#  18,
#  1,
#  6,
#  19,
#  9,
#  14,
#  21,
#  16,
#  10,
#  8,
#  20,
#  5,
#  12,
#  3,
#  11,
#  2,
#  22,
#  7,
#  4,
#  15,
#  17,
#  0]

# %%
fea1 = ['months_as_customer', 'policy_state', 'policy_deductable', 'insured_sex','insured_education_level',
    'insured_occupation', 'insured_hobbies', 'insured_relationship','incident_type','auto_make','auto_year',
    'age_boxcox', 'policy_annual_premium_boxcox', 'total_claim_amount_boxcox','insurance_age','vehicle_age',
    'fraud_reported'
]

fea2 = ['months_as_customer', 'policy_state', 'policy_deductable', 'insured_sex','insured_education_level',
    'insured_occupation', 'insured_hobbies', 'insured_relationship','incident_type','auto_make','auto_year',
    'age_boxcox', 'policy_annual_premium_boxcox', 'total_claim_amount_boxcox','insurance_age','vehicle_age',
    'fraud_reported','incident_severity', 'property_damage', 'bodily_injuries',  'property_claim_cube']

fea3 = ['months_as_customer', 'policy_state', 'policy_deductable', 'insured_sex','insured_education_level',
    'insured_occupation', 'insured_hobbies', 'insured_relationship','incident_type','auto_make','auto_year',
    'age_boxcox', 'policy_annual_premium_boxcox', 'total_claim_amount_boxcox','insurance_age','vehicle_age',
    'incident_severity', 'property_damage', 'bodily_injuries',  'property_claim_cube','incident_hour_of_the_day'
    ,'authorities_contacted','number_of_vehicles_involved','police_report_available','fraud_reported']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   months_as_customer            1000 non-null   int16
#  1   policy_bind_date              1000 non-null   datetime64[ns]
#  2   policy_state                  1000 non-null   category
#  3   policy_deductable             1000 non-null   int16
#  4   insured_sex                   1000 non-null   category
#  5   insured_education_level       1000 non-null   category
#  6   insured_occupation            1000 non-null   category
#  7   insured_hobbies               1000 non-null   category
#  8   insured_relationship          1000 non-null   category
#  9   incident_date                 1000 non-null   datetime64[ns]
#  10  incident_type                 1000 non-null   category
#  11  collision_type                1000 non-null   category
#  12  incident_severity             1000 non-null   category
#  13  authorities_contacted         1000 non-null   category
#  14  incident_state                1000 non-null   category
#  15  incident_city                 1000 non-null   category
#  16  incident_hour_of_the_day      1000 non-null   category
#  17  number_of_vehicles_involved   1000 non-null   category
#  18  property_damage               1000 non-null   category
#  19  bodily_injuries               1000 non-null   category
#  20  witnesses                     1000 non-null   category
#  21  police_report_available       1000 non-null   category
#  22  auto_make                     1000 non-null   category
#  23  auto_year                     1000 non-null   category
#  24  fraud_reported                1000 non-null   category
#  25  age_boxcox                    1000 non-null   float64
#  26  policy_annual_premium_boxcox  1000 non-null   float64
#  27  total_claim_amount_boxcox     1000 non-null   float64
#  28  injury_claim_cube             1000 non-null   int16
#  29  property_claim_cube           1000 non-null   int16
#  30  vehicle_claim_boxcox          1000 non-null   float64
#  31  insurance_age                 1000 non-null   int8
#  32  vehicle_age                   1000 non-null   int8
# dtypes: category(21), datetime64[ns](2), float64(4), int16(4), int8(2)
# memory usage: 83.9 KB

# %% [markdown]
# ## <span style="color:Aqua;"> Encoding Categorical Features:</span>

# %%
insured_sex_map = { 'FEMALE': 0,'MALE':1  }
property_damage_map = { 'NO':0, 'YES':1 }
police_report_available_map = { 'NO':0, 'YES':1 }
fraud_reported_map = { 'N':0, 'Y':1 }

# %%
df['insured_sex'] = pd.to_numeric(df['insured_sex'].map(insured_sex_map),errors='raise',downcast='integer')
df['property_damage'] = pd.to_numeric(df['property_damage'].map(property_damage_map),errors='raise',downcast='integer')
df['police_report_available'] = pd.to_numeric(df['police_report_available'].map(police_report_available_map),errors='raise',downcast='integer')
df['fraud_reported'] = pd.to_numeric(df['fraud_reported'].map(fraud_reported_map),errors='raise',downcast='integer')

# %%
policy_state = pd.get_dummies(df['policy_state'],prefix = 'policy_state_', dtype='int8')
insured_occupation = pd.get_dummies(df['insured_occupation'],prefix = 'insured_occ_',dtype='int8')
insured_hobbies = pd.get_dummies(df['insured_hobbies'],prefix = 'insured_hobbies_',dtype='int8')
insured_relationship = pd.get_dummies(df['insured_relationship'],prefix = 'insured_rela_',dtype='int8')
incident_type = pd.get_dummies(df['incident_type'],prefix = 'incident_type_',dtype='int8')
collision_type = pd.get_dummies(df['collision_type'],prefix = 'collision_type_',dtype='int8')
authorities_contacted = pd.get_dummies(df['authorities_contacted'],prefix = 'authorities_contacted_',dtype='int8')
incident_state = pd.get_dummies(df['incident_state'],prefix = 'incident_state_',dtype='int8')
incident_city = pd.get_dummies(df['incident_city'],prefix = 'incident_city_',dtype='int8')
auto_make = pd.get_dummies(df['auto_make'],prefix = 'auto_make_',dtype='int8')

en = LabelEncoder()
df['insured_education_level'] = en.fit_transform(df['insured_education_level']).astype('int8')

en1 = LabelEncoder()
df['incident_severity'] = en.fit_transform(df['incident_severity']).astype('int8')


df1= pd.concat([df,policy_state,insured_hobbies,insured_occupation,insured_relationship,incident_type,collision_type,
                authorities_contacted,incident_state,incident_city,auto_make],axis=1)
df1 = df1.drop(['policy_state','insured_hobbies','insured_occupation','insured_relationship','incident_type','collision_type',
                'authorities_contacted','incident_state','incident_city','auto_make'],axis=1)

# %%
policy_state_ohe = [col for col in df1.columns if 'policy_state_' in col]
insured_occupation_ohe = [col for col in df1.columns if 'insured_occupation_' in col]
insured_hobbies_ohe = [col for col in df1.columns if 'insured_hobbies_' in col]
insured_relationship_ohe = [col for col in df1.columns if 'insured_rela_' in col]
incident_type_ohe = [col for col in df1.columns if 'incident_type_' in col]
collision_type_ohe = [col for col in df1.columns if 'collision_type_' in col]
authorities_contacted_ohe = [col for col in df1.columns if 'authorities_contacted_' in col]
incident_state_ohe = [col for col in df1.columns if 'incident_state_' in col]
incident_city_ohe = [col for col in df1.columns if 'incident_city_' in col]
auto_make_ohe = [col for col in df1.columns if 'auto_make_' in col]

# %%
fea1 = ['months_as_customer',  'policy_deductable', 'insured_sex','auto_year','insured_education_level',
    'age_boxcox', 'policy_annual_premium_boxcox', 'total_claim_amount_boxcox','insurance_age','vehicle_age',
    'fraud_reported'
]

fea1.extend(collision_type_ohe + insured_occupation_ohe + insured_hobbies_ohe + insured_relationship_ohe +
            incident_type_ohe )

fea2 = ['months_as_customer', 'policy_deductable', 'insured_sex','insured_education_level','auto_year',
    'age_boxcox', 'policy_annual_premium_boxcox', 'total_claim_amount_boxcox','insurance_age','vehicle_age',
    'fraud_reported','incident_severity', 'property_damage', 'bodily_injuries',  'property_claim_cube']

fea2.extend(policy_state_ohe + insured_occupation_ohe + insured_hobbies_ohe + insured_relationship_ohe + incident_type_ohe +
                   auto_make_ohe + incident_city_ohe)

fea3 = ['months_as_customer', 'policy_deductable', 'insured_sex','insured_education_level','auto_year',
    'age_boxcox', 'policy_annual_premium_boxcox', 'total_claim_amount_boxcox','insurance_age','vehicle_age',
    'incident_severity', 'property_damage', 'bodily_injuries',  'property_claim_cube','incident_hour_of_the_day'
    ,'number_of_vehicles_involved','police_report_available','fraud_reported']

fea3.extend(policy_state_ohe + insured_occupation_ohe + insured_hobbies_ohe + insured_relationship_ohe + incident_type_ohe +
                   auto_make_ohe + authorities_contacted_ohe + incident_city_ohe)

# %%
feature_sets = {
    'fea1': fea1,
    'fea2': fea2,
    'fea3': fea3
}

# %% [markdown]
# # <span style="color:Tomato;">Training the model without scaling the dataset:</span>
#
# #### <span style="color:Aqua;">I am going to use KMeans clustering for our problem. Hiearchical Clustering may not useful since we have more data point and variety of data.</span>

# %% [markdown]
# ## <span style="color:Aqua;">Evaluation Metrics Interpretation:</span>

# %% [markdown]
# <span style="color:Khaki;"> Interpretation of silhouette scores:
#
# - 1 to 0: Poor clustering, with many points assigned to the wrong clusters.
# - 0 to 0.25: Weak structure, which might indicate overlapping clusters.
# - 0.25 to 0.50: Reasonable clustering.
# - 0.50 to 0.75: Good clustering.
# - 0.75 to 1: Strong clustering, indicating well-defined clusters.
#
# <span style="color:Khaki;"> Interpretation of Calinski-Harabasz Index: </span>
#
# - Higher is better.
# - Measures the ratio of the sum of between-cluster dispersion and within-cluster dispersion.
#
# <span style="color:Khaki;"> Interpretation of Davies-Bouldin Index: </span>
#
# - Range: 0 to ∞
# -  Lower values indicate better clustering.
# - Measures the average similarity ratio of each cluster with its most similar cluster.

# %% [markdown]
# ## <span style="color:Aqua;">Training the model with all relevant Features:</span>

# %% [markdown]
# ### <span style="color:Khaki;">Finding K value using Elbow method:

# %%
wcss = {}
for name, features in feature_sets.items():
    wcss[name] = []
    for k in range(1,6):
        kmeans = KMeans(n_clusters=k,init='k-means++',random_state=42)
        kmeans.fit(df1[features])
        wcss[name].append(kmeans.inertia_)

print(wcss)
# Out:
# {'fea1': [3263193957375.5234, 946288888750.7147, 363582831955.548, 197250648662.5917, 119465941261.87093], 'fea2': [3616502169433.4014, 1299505570510.4424, 716411114560.7101, 549577066605.8137, 445596067140.97424], 'fea3': [3616502219717.4976, 1299505618414.3196, 716411162179.51, 549577113733.07935, 445596114134.4911]}

# %% [markdown]
# #### <span style="color:Khaki;">Plotting Within-Cluster Sum of Squares (WCSS) values to find the Elbow:

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)
clusters = range(1, 6)

for ax, (name, inertia) in zip(axes, wcss.items()):
    ax.plot(clusters, inertia, marker='o', linestyle='-', label=name)
    ax.set_title(name)
    ax.set_xticks(clusters)
    ax.set_xlabel('Number of clusters')
    ax.set_ylabel('WCSS')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <span style="color:DodgerBlue;">From the above plot we can see that the Knee is located near the value 2

# %% [markdown]
# #### <span style="color:Khaki;">Finding knee locator in the Elbow curve using KneeLocator class:

# %%
optimal_k_wcss = {}

for name, inertia in wcss.items():
    kl = KneeLocator(range(1, 6), inertia, curve='convex', direction='decreasing')
    optimal_k_wcss[name] = kl.elbow

print(optimal_k_wcss)
# Out:
# {'fea1': np.int64(2), 'fea2': np.int64(2), 'fea3': np.int64(2)}

# %% [markdown]
# <span style="color:DodgerBlue;">Knee Locator also confirms that the Knee is located near the value 2

# %% [markdown]
# ### <span style="color:Khaki;">Finding K value using silhouette score method:

# %%
silhouette_coefficients = {}
for name, features in feature_sets.items():
    silhouette_coefficients[name] = []
    for k in range(2,6):
        kmeans = KMeans(n_clusters=k,init='k-means++',random_state=42)
        kmeans.fit(df1[features])
        score = silhouette_score(df1[features],kmeans.labels_)
        silhouette_coefficients[name].append(score)

print(silhouette_coefficients)
# Out:
# {'fea1': [np.float64(0.6792746724126905), np.float64(0.6181538338887242), np.float64(0.596403513075476), np.float64(0.6051302760912008)], 'fea2': [np.float64(0.5974657217337447), np.float64(0.4702658814518599), np.float64(0.3949255755466923), np.float64(0.4086051507167083)], 'fea3': [np.float64(0.5974657075167095), np.float64(0.4702658533113155), np.float64(0.3949255362834871), np.float64(0.4086051010071519)]}

# %% [markdown]
# <span style="color:DodgerBlue;">THe highest silouette scode we obtaine is around 60 from fea1.

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)

for ax, (name, scores) in zip(axes, silhouette_coefficients.items()):
    ax.plot(range(2, 6), scores, marker='o', linestyle='-', label=name)
    ax.set_title(name)
    ax.set_xticks(range(2, 6))
    ax.set_xlabel('Number of clusters')
    ax.set_ylabel('Silhouette Coefficient')
    ax.legend()
    ax.grid(True)

plt.suptitle('Silhouette Coefficients for Different Feature Sets')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# <span style="color:DodgerBlue;">We can see the highest Silhouette score is near the vale2  The Silhouette score also confirms that the Knee is located near the value 2.

# %%
optimal_k_silhouette = {}

for name, scores in silhouette_coefficients.items():
    optimal_k = range(2, 6)[scores.index(max(scores))]
    optimal_k_silhouette[name] = optimal_k
    
for name, optimal_k in optimal_k_silhouette.items():
    print(f"Optimal number of clusters for {name} (Silhouette): {optimal_k}")
# Out:
# Optimal number of clusters for fea1 (Silhouette): 2
# Optimal number of clusters for fea2 (Silhouette): 2
# Optimal number of clusters for fea3 (Silhouette): 2

# %% [markdown]
# <span style="color:DodgerBlue;"> Both WCSS and Silhouette confirms that the possible and meaningful cluster is 2 when we use all relevant features.

# %% [markdown]
# #### <span style="color:Khaki;"> Differnciating cluters using PCA and visualizing via Scatter plot:

# %%
fig, axes = plt.subplots(1, 3, figsize=(25, 10), sharex=True, sharey=True)

for ax, (name, features) in zip(axes, feature_sets.items()):
    pca = PCA(n_components=2)
    x_pca = pca.fit_transform(df1[features])
    
    kmeans = KMeans(n_clusters=2, init='k-means++', random_state=42)
    labels = kmeans.fit_predict(df1[features])
    
    scatter = ax.scatter(x_pca[:, 0], x_pca[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k')
    ax.set_title(f'Clusters for {name}')
    ax.set_xlabel('PCA Component 1')
    ax.set_ylabel('PCA Component 2')
    
plt.colorbar(scatter, ax=axes, orientation='horizontal', fraction=0.02, pad=0.1)
plt.show()

# %% [markdown]
# This suggests that the simpler model with fewer features (fea1) is more effective at creating distinct, well-separated clusters. The additional features in fea2 and fea3 may be introducing noise or redundant information that doesn't improve the clustering performance.

# %% [markdown]
# # <span style="color:Tomato;">Training the model after scaling the dataset:</span>

# %% [markdown]
# #### <span style="color:Khaki;"> Scaling the data:

# %%
continuous_features = ['months_as_customer', 'policy_deductable', 'auto_year', 'age_boxcox', 
                       'policy_annual_premium_boxcox', 'total_claim_amount_boxcox', 
                       'insurance_age', 'vehicle_age']

categorical_features = [col for col in fea1 if col not in continuous_features]

# %%
df1[fea1].shape
# Out:
# (1000, 65)

# %%
scales = {'std_scale' : StandardScaler(),
'mm_scale' : MinMaxScaler(feature_range=(0,1)),
'rob_scale' : RobustScaler()
}
scaled_dfs = {}
for scaler_name, scaler in scales.items():
    scaled_continuous = scaler.fit_transform(df1[continuous_features])
    scaled_df = np.hstack((scaled_continuous, df1[categorical_features].values))

    scaled_dfs[scaler_name] = scaled_df
    print(scaler_name, '---', scaled_df.shape)
# Out:
# std_scale --- (1000, 65)
# mm_scale --- (1000, 65)
# rob_scale --- (1000, 65)

# %% [markdown]
# #### <span style="color:Khaki;"> Training the model:

# %%
silhouette_avg = {}
calinski_harabasz = {}
davies_bouldin = {}
labels = {}

for scaler_name, scaled_df in scaled_dfs.items():
    kmeans = KMeans(n_clusters=2, random_state=42)
    kmeans.fit(scaled_df)
    labels[scaler_name] = kmeans.labels_

    silhouette_avg[scaler_name] = silhouette_score(scaled_df, kmeans.labels_)
    calinski_harabasz[scaler_name] = calinski_harabasz_score(scaled_df, kmeans.labels_)
    davies_bouldin[scaler_name] = davies_bouldin_score(scaled_df, kmeans.labels_)

# %%
print(f"silhouette_avg -- {silhouette_avg}")
print(f"calinski_harabasz -- {calinski_harabasz}")
print(f"davies_bouldin -- {davies_bouldin}")
[f"{scaler_name} -- {np.unique(labels['mm_scale'])}" for scaler_name in labels.keys()]
# Out:
# silhouette_avg -- {'std_scale': np.float64(0.14634134941797308), 'mm_scale': np.float64(0.23401507305350136), 'rob_scale': np.float64(0.18687074356103933)}
# calinski_harabasz -- {'std_scale': np.float64(194.5846421936575), 'mm_scale': np.float64(399.41078972536474), 'rob_scale': np.float64(279.05327037533715)}
# davies_bouldin -- {'std_scale': np.float64(2.22013269080217), 'mm_scale': np.float64(1.5459334232496538), 'rob_scale': np.float64(1.8449032034466526)}
# ['std_scale -- [0 1]', 'mm_scale -- [0 1]', 'rob_scale -- [0 1]']

# %% [markdown]
# ### <span style="color:Tomato;"> The model's clustering quality is good when we use direct dataset rather than scaled data. So we are going to model without scaling the data. Silouette score is good when we use Original features so we will use this for modeling.

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import pandas as pd

# Ensure continuous_features only contains numerical columns
continuous_features = df1.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_features = df1.select_dtypes(include=['category', 'object']).columns.tolist()

# PCA for feature importance
pca = PCA()
pca_result = pca.fit_transform(scaled_dfs['mm_scale'])

# Plot cumulative explained variance ratio
plt.figure(figsize=(10, 6))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA Cumulative Explained Variance')
plt.show()

# t-SNE for visualization
tsne = TSNE(n_components=2, random_state=42)
tsne_result = tsne.fit_transform(scaled_dfs['mm_scale'])

plt.figure(figsize=(10, 6))
plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=labels['mm_scale'])
plt.title('t-SNE visualization of clusters')
plt.show()

# Analyze cluster characteristics
cluster_0 = df1[labels['mm_scale'] == 0]
cluster_1 = df1[labels['mm_scale'] == 1]

print("Cluster 0 mean values:")
print(cluster_0[continuous_features].mean())
print("\nCluster 1 mean values:")
print(cluster_1[continuous_features].mean())

# For categorical features, look at the most common values in each cluster
for feature in categorical_features:
    print(f"\nMost common {feature} in Cluster 0:", cluster_0[feature].value_counts().index[0])
    print(f"Most common {feature} in Cluster 1:", cluster_1[feature].value_counts().index[0])

# Additional analysis: distribution of categorical variables
for feature in categorical_features:
    plt.figure(figsize=(12, 6))
    cluster_0[feature].value_counts(normalize=True).plot(kind='bar', alpha=0.5, label='Cluster 0')
    cluster_1[feature].value_counts(normalize=True).plot(kind='bar', alpha=0.5, label='Cluster 1')
    plt.title(f'Distribution of {feature} in Clusters')
    plt.legend()
    plt.show()
# Out:
# Cluster 0 mean values:
# age_boxcox                          4.1725
# policy_annual_premium_boxcox     1264.2658
# total_claim_amount_boxcox      106819.0922
# vehicle_claim_boxcox            86043.6692
# dtype: float64
#
# Cluster 1 mean values:
# age_boxcox                          4.2010
# policy_annual_premium_boxcox     1253.4981
# total_claim_amount_boxcox      115320.7318
# vehicle_claim_boxcox            92671.0227
# dtype: float64
#
# Most common incident_hour_of_the_day in Cluster 0: 16
# Most common incident_hour_of_the_day in Cluster 1: 3
#
# Most common number_of_vehicles_involved in Cluster 0: 1
# Most common number_of_vehicles_involved in Cluster 1: 1
#
# Most common bodily_injuries in Cluster 0: 1
# Most common bodily_injuries in Cluster 1: 0
#
# Most common witnesses in Cluster 0: 0
# Most common witnesses in Cluster 1: 1
#
# Most common auto_year in Cluster 0: 1999
# Most common auto_year in Cluster 1: 2006

# %% [markdown]
# ## <span style="color:Aqua;">Creating cluster using the Original Features:</span>

# %%
fea1
# Out:
# ['months_as_customer',
#  'policy_deductable',
#  'insured_sex',
#  'auto_year',
#  'insured_education_level',
#  'age_boxcox',
#  'policy_annual_premium_boxcox',
#  'total_claim_amount_boxcox',
#  'insurance_age',
#  'vehicle_age',
#  'fraud_reported',
#  'policy_state__IL',
#  'policy_state__IN',
#  'policy_state__OH',
#  'insured_hobbies__base-jumping',
#  'insured_hobbies__basketball',
#  'insured_hobbies__board-games',
#  'insured_hobbies__bungie-jumping',
#  'insured_hobbies__camping',
#  'insured_hobbies__chess',
#  'insured_hobbies__cross-fit',
#  'insured_hobbies__dancing',
#  'insured_hobbies__exercise',
#  'insured_hobbies__golf',
#  'insured_hobbies__hiking',
#  'insured_hobbies__kayaking',
#  'insured_hobbies__movies',
#  'insured_hobbies__paintball',
#  'insured_hobbies__polo',
#  'insured_hobbies__reading',
#  'insured_hobbies__skydiving',
#  'insured_hobbies__sleeping',
#  'insured_hobbies__video-games',
#  'insured_hobbies__yachting',
#  'insured_rela__husband',
#  'insured_rela__not-in-family',
#  'insured_rela__other-relative',
#  'insured_rela__own-child',
#  'insured_rela__unmarried',
#  'insured_rela__wife',
#  'incident_type__Multi-vehicle Collision',
#  'incident_type__Parked Car',
#  'incident_type__Single Vehicle Collision',
#  'incident_type__Vehicle Theft',
#  'auto_make__Accura',
#  'auto_make__Audi',
#  'auto_make__BMW',
#  'auto_make__Chevrolet',
#  'auto_make__Dodge',
#  'auto_make__Ford',
#  'auto_make__Honda',
#  'auto_make__Jeep',
#  'auto_make__Mercedes',
#  'auto_make__Nissan',
#  'auto_make__Saab',
#  'auto_make__Suburu',
#  'auto_make__Toyota',
#  'auto_make__Volkswagen',
#  'incident_city__Arlington',
#  'incident_city__Columbus',
#  'incident_city__Hillsdale',
#  'incident_city__Northbend',
#  'incident_city__Northbrook',
#  'incident_city__Riverwood',
#  'incident_city__Springfield']

# %%
'age_boxcox',
         'policy_annual_premium_boxcox', 'total_claim_amount_boxcox','policy_state__IL', 'policy_state__IN', 'policy_state__OH',
# Out:
#   Cell In[44], line 2
#     'policy_annual_premium_boxcox', 'total_claim_amount_boxcox',
#     ^
# IndentationError: unexpected indent

# %%
df.columns
# Out:
# Index(['months_as_customer', 'policy_bind_date', 'policy_state',
#        'policy_deductable', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_hobbies', 'insured_relationship',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'auto_make', 'auto_year', 'fraud_reported',
#        'age_boxcox', 'policy_annual_premium_boxcox',
#        'total_claim_amount_boxcox', 'injury_claim_cube', 'property_claim_cube',
#        'vehicle_claim_boxcox', 'insurance_age', 'vehicle_age'],
#       dtype='object')

# %%
fea1 = ['months_as_customer', 'policy_deductable', 'insured_sex', 'auto_year', 'insured_education_level',  'insurance_age', 'vehicle_age', 'fraud_reported',
          'insured_hobbies__base-jumping', 'insured_hobbies__basketball', 'auto_year',
         'insured_hobbies__board-games', 'insured_hobbies__bungie-jumping', 'insured_hobbies__camping', 'insured_hobbies__chess',
         'insured_hobbies__cross-fit', 'insured_hobbies__dancing', 'insured_hobbies__exercise', 'insured_hobbies__golf', 'insured_hobbies__hiking',
         'insured_hobbies__kayaking', 'insured_hobbies__movies', 'insured_hobbies__paintball', 'insured_hobbies__polo', 'insured_hobbies__reading',
         'insured_hobbies__skydiving', 'insured_hobbies__sleeping', 'insured_hobbies__video-games', 'insured_hobbies__yachting', 'insured_rela__husband',
         'insured_rela__not-in-family', 'insured_rela__other-relative', 'insured_rela__own-child', 'insured_rela__unmarried', 'insured_rela__wife',
         'incident_type__Multi-vehicle Collision', 'incident_type__Parked Car', 'incident_type__Single Vehicle Collision', 'incident_type__Vehicle Theft',
        ]

# %%
fea1.extend(collision_type_ohe)

# %%
fea1
# Out:
# ['months_as_customer',
#  'policy_deductable',
#  'insured_sex',
#  'auto_year',
#  'insured_education_level',
#  'insurance_age',
#  'vehicle_age',
#  'fraud_reported',
#  'insured_hobbies__base-jumping',
#  'insured_hobbies__basketball',
#  'auto_year',
#  'insured_hobbies__board-games',
#  'insured_hobbies__bungie-jumping',
#  'insured_hobbies__camping',
#  'insured_hobbies__chess',
#  'insured_hobbies__cross-fit',
#  'insured_hobbies__dancing',
#  'insured_hobbies__exercise',
#  'insured_hobbies__golf',
#  'insured_hobbies__hiking',
#  'insured_hobbies__kayaking',
#  'insured_hobbies__movies',
#  'insured_hobbies__paintball',
#  'insured_hobbies__polo',
#  'insured_hobbies__reading',
#  'insured_hobbies__skydiving',
#  'insured_hobbies__sleeping',
#  'insured_hobbies__video-games',
#  'insured_hobbies__yachting',
#  'insured_rela__husband',
#  'insured_rela__not-in-family',
#  'insured_rela__other-relative',
#  'insured_rela__own-child',
#  'insured_rela__unmarried',
#  'insured_rela__wife',
#  'incident_type__Multi-vehicle Collision',
#  'incident_type__Parked Car',
#  'incident_type__Single Vehicle Collision',
#  'incident_type__Vehicle Theft',
#  'collision_type__Front Collision',
#  'collision_type__Others',
#  'collision_type__Rear Collision',
#  'collision_type__Side Collision']

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(df1[fea1])
df1['Cluster'] = kmeans.predict(df1[fea1])
silhouette = silhouette_score(df1[fea1], kmeans.labels_)
calinski_harabasz = calinski_harabasz_score(df1[fea1], kmeans.labels_)
davies_bouldin = davies_bouldin_score(df1[fea1], kmeans.labels_)

# %%
print(f"Clusters unique values -- {np.unique(kmeans.labels_)} \nSilhouette Score -- {silhouette} \
      \ncalinski_harabasz Score -- {calinski_harabasz} \ndavies_bouldin -- {davies_bouldin}")
# Out:
# Clusters unique values -- [0 1]
# Silhouette Score -- 0.7786414920873165
# calinski_harabasz Score -- 5821.856036613691
# davies_bouldin -- 0.2976675807911426

# %%
pd.set_option('display.max_rows', None)  # Display all rows
pd.set_option('display.max_columns', None)  # Display all columns   

# Create DataFrame of cluster centroids
centroids = pd.DataFrame(kmeans.cluster_centers_, columns=fea1)
print("Cluster Centroids:")
# print(centroids)

# Calculate feature-wise variance across clusters
cluster_variance = np.var(kmeans.cluster_centers_, axis=0)

# Calculate silhouette score
silhouette_avg = silhouette_score(df1[fea1], kmeans.labels_)
print("Silhouette Score:", silhouette_avg)

# Combine feature variance and silhouette score
importance = pd.DataFrame({'Feature': fea1, 'Cluster Variance': cluster_variance, 'Silhouette Score': silhouette_avg})
importance = importance.sort_values(by=['Cluster Variance', 'Silhouette Score'], ascending=[False, True])

print("Feature Importance:")
print(importance)
# Out:
# Cluster Centroids:
# Silhouette Score: 0.7786414920873165
# Feature Importance:
#                                     Feature  Cluster Variance  \
# 1                         policy_deductable       388598.4146
# 0                        months_as_customer           23.4641
# 5                             insurance_age            0.1074
# 3                                 auto_year            0.0281
# 10                                auto_year            0.0281
# 6                               vehicle_age            0.0281
# 4                   insured_education_level            0.0017
# 35   incident_type__Multi-vehicle Collision            0.0010
# 39          collision_type__Front Collision            0.0008
# 37  incident_type__Single Vehicle Collision            0.0008
# 42           collision_type__Side Collision            0.0003
# 27             insured_hobbies__video-games            0.0003
# 34                       insured_rela__wife            0.0002
# 7                            fraud_reported            0.0001
# 36                incident_type__Parked Car            0.0001
# 28                insured_hobbies__yachting            0.0001
# 25               insured_hobbies__skydiving            0.0001
# 18                    insured_hobbies__golf            0.0001
# 12          insured_hobbies__bungie-jumping            0.0001
# 38             incident_type__Vehicle Theft            0.0001
# 13                 insured_hobbies__camping            0.0000
# 32                  insured_rela__own-child            0.0000
# 33                  insured_rela__unmarried            0.0000
# 41           collision_type__Rear Collision            0.0000
# 21                  insured_hobbies__movies            0.0000
# 19                  insured_hobbies__hiking            0.0000
# 15               insured_hobbies__cross-fit            0.0000
# 40                   collision_type__Others            0.0000
# 30              insured_rela__not-in-family            0.0000
# 9               insured_hobbies__basketball            0.0000
# 11             insured_hobbies__board-games            0.0000
# 2                               insured_sex            0.0000
# 8             insured_hobbies__base-jumping            0.0000
# 14                   insured_hobbies__chess            0.0000
# 16                 insured_hobbies__dancing            0.0000
# 24                 insured_hobbies__reading            0.0000
# 26                insured_hobbies__sleeping            0.0000
# 23                    insured_hobbies__polo            0.0000
# 22               insured_hobbies__paintball            0.0000
# 17                insured_hobbies__exercise            0.0000
# 20                insured_hobbies__kayaking            0.0000
# 31             insured_rela__other-relative            0.0000
# 29                    insured_rela__husband            0.0000
#
#     Silhouette Score
# 1             0.7786
# 0             0.7786
# 5             0.7786
# 3             0.7786
# 10            0.7786
# 6             0.7786
# 4             0.7786
# 35            0.7786
# 39            0.7786
# 37            0.7786
# 42            0.7786
# 27            0.7786
# 34            0.7786
# 7             0.7786
# 36            0.7786
# 28            0.7786
# 25            0.7786
# 18            0.7786
# 12            0.7786
# 38            0.7786
# 13            0.7786
# 32            0.7786
# 33            0.7786
# 41            0.7786
# 21            0.7786
# 19            0.7786
# 15            0.7786
# 40            0.7786
# 30            0.7786
# 9             0.7786
# 11            0.7786
# 2             0.7786
# 8             0.7786
# 14            0.7786
# 16            0.7786
# 24            0.7786
# 26            0.7786
# 23            0.7786
# 22            0.7786
# 17            0.7786
# 20            0.7786
# 31            0.7786
# 29            0.7786

# %%
cluster_variance = np.var(kmeans.cluster_centers_, axis=0)
importance = pd.DataFrame({'Feature': fea1, 'Variance': cluster_variance})
print(importance.sort_values(by='Variance', ascending=False))
# Out:
#                          Feature        Variance
# 7      total_claim_amount_boxcox 3270616743.2444
# 1              policy_deductable        146.0126
# 6   policy_annual_premium_boxcox         73.0203
# 0             months_as_customer         17.3749
# 8                  insurance_age          0.0602
# ..                           ...             ...
# 50              auto_make__Honda          0.0000
# 30    insured_hobbies__skydiving          0.0000
# 11              policy_state__IL          0.0000
# 45               auto_make__Audi          0.0000
# 64    incident_city__Springfield          0.0000
#
# [65 rows x 2 columns]

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(df1[fea1])
df['Cluster'] = kmeans.predict(df1[fea1])
silhouette = silhouette_score(df1[fea1], kmeans.labels_)
calinski_harabasz = calinski_harabasz_score(df1[fea1], kmeans.labels_)
davies_bouldin = davies_bouldin_score(df1[fea1], kmeans.labels_)

# %%
df1.to_feather('clustered.feather')

# %%
# Set up the figure and subplots
fig, ax = plt.subplots(figsize=(6, 4))

# Perform PCA
pca = PCA(n_components=2)
x_pca = pca.fit_transform(df1.select_dtypes(include='number'))

# Re-run KMeans on PCA results
kmeans = KMeans(n_clusters=2, init='k-means++', random_state=42)
labels = kmeans.fit_predict(df1.select_dtypes(include='number'))

# Create scatter plot
scatter = ax.scatter(x_pca[:, 0], x_pca[:, 1], c=labels, cmap='viridis', marker='o')

# Set title and labels
ax.set_title(f'Clusters visualized using PCA')
ax.set_xlabel('PCA Component 1')
ax.set_ylabel('PCA Component 2')

# Add color bar for cluster labels
plt.colorbar(scatter, ax=ax)

# Show the plot
plt.show()

# %% [markdown]
# # <span style="color:Tomato;">Results Interpretation:</span>

# %% [markdown]
# - <span style="color:Aqua;"> Algorithm: </span> KMeans with n_clusters=2.
# - <span style="color:Aqua;"> Metrics: </span>
#     - <span style="color:Khaki;">Silhouette Score:</span> 0.679 (indicates good cluster separation).
#     - <span style="color:Khaki;">Calinski-Harabasz Score:</span> 2443.515 (suggests well-separated and dense clusters).
#     - <span style="color:Khaki;">Davies-Bouldin Score:</span> 0.402 (indicates well-separated clusters).
# - <span style="color:Aqua;"> Cluster Characteristics:</span>
#     - <span style="color:Khaki;">Cluster 0:</span> Higher values in features such as incident_hour_of_the_day, number_of_vehicles_involved, and bodily_injuries.
#     - <span style="color:Khaki;"> Cluster 1:</span> Lower values in these features.
# - <span style="color:Aqua;"> Cluster Analysis:</span> Shows distinct patterns between clusters, useful for segmenting policyholders.

# %% [markdown]
# ## <span style="color:Aqua;">Clusters Summary:</span>

# %%
cluster_centroids = df1.groupby('Cluster').describe()
cluster_centroids
# Out:
#         months_as_customer                                             \
#                      count     mean    min      25%      50%      75%
# Cluster
# 0                 770.0000 205.8714 0.0000 116.0000 201.0000 278.0000
# 1                 230.0000 197.5348 1.0000 114.2500 197.5000 273.2500
#
#                           policy_bind_date                                 \
#              max      std            count                           mean
# Cluster
# 0       479.0000 117.0969              770  2002-03-22 15:27:35.064935040
# 1       478.0000 108.2048              230  2001-09-19 01:58:57.391304320
#
#                                                                         \
#                          min                  25%                  50%
# Cluster
# 0        1990-01-08 00:00:00  1995-12-05 06:00:00  2002-05-13 00:00:00
# 1        1990-03-14 00:00:00  1995-04-12 12:00:00  2001-10-04 12:00:00
#
#                                                        policy_deductable  \
#                          75%                  max  std             count
# Cluster
# 0        2008-06-25 00:00:00  2015-02-22 00:00:00  NaN          770.0000
# 1        2007-06-26 00:00:00  2015-01-17 00:00:00  NaN          230.0000
#
#                                                                             \
#              mean      min      25%       50%       75%       max      std
# Cluster
# 0       1141.5584 500.0000 500.0000 1000.0000 2000.0000 2000.0000 614.1696
# 1       1117.3913 500.0000 500.0000 1000.0000 2000.0000 2000.0000 605.0386
#
#         insured_sex                                                   \
#               count   mean    min    25%    50%    75%    max    std
# Cluster
# 0          770.0000 0.4675 0.0000 0.0000 0.0000 1.0000 1.0000 0.4993
# 1          230.0000 0.4478 0.0000 0.0000 0.0000 1.0000 1.0000 0.4984
#
#         insured_education_level                                            \
#                           count   mean    min    25%    50%    75%    max
# Cluster
# 0                      770.0000 3.0312 0.0000 1.0000 3.0000 5.0000 6.0000
# 1                      230.0000 2.7478 0.0000 1.0000 3.0000 4.0000 6.0000
#
#                incident_date                                 \
#            std         count                           mean
# Cluster
# 0       1.9343           770  2015-01-29 20:58:35.844155904
# 1       1.9840           230  2015-01-31 21:04:41.739130368
#
#                                                                         \
#                          min                  25%                  50%
# Cluster
# 0        2015-01-01 00:00:00  2015-01-14 00:00:00  2015-01-30 00:00:00
# 1        2015-01-01 00:00:00  2015-01-18 00:00:00  2015-02-02 00:00:00
#
#                                                        incident_severity  \
#                          75%                  max  std             count
# Cluster
# 0        2015-02-14 00:00:00  2015-03-01 00:00:00  NaN          770.0000
# 1        2015-02-16 00:00:00  2015-03-01 00:00:00  NaN          230.0000
#
#                                                          property_damage  \
#           mean    min    25%    50%    75%    max    std           count
# Cluster
# 0       0.9987 0.0000 0.0000 1.0000 2.0000 2.0000 0.8278        770.0000
# 1       1.8043 0.0000 1.0000 1.0000 3.0000 3.0000 1.0242        230.0000
#
#                                                           \
#           mean    min    25%    50%    75%    max    std
# Cluster
# 0       0.6636 0.0000 0.0000 1.0000 1.0000 1.0000 0.4728
# 1       0.6261 0.0000 0.0000 1.0000 1.0000 1.0000 0.4849
#
#         police_report_available                                            \
#                           count   mean    min    25%    50%    75%    max
# Cluster
# 0                      770.0000 0.3481 0.0000 0.0000 0.0000 1.0000 1.0000
# 1                      230.0000 0.4130 0.0000 0.0000 0.0000 1.0000 1.0000
#
#                fraud_reported                                            \
#            std          count   mean    min    25%    50%    75%    max
# Cluster
# 0       0.4767       770.0000 0.2870 0.0000 0.0000 0.0000 1.0000 1.0000
# 1       0.4935       230.0000 0.1130 0.0000 0.0000 0.0000 0.0000 1.0000
#
#                age_boxcox                                                   \
#            std      count   mean    min    25%    50%    75%    max    std
# Cluster
# 0       0.4527   770.0000 4.1899 3.2967 3.9605 4.1851 4.4089 4.8844 0.3142
# 1       0.3173   230.0000 4.1655 3.5909 3.9296 4.1851 4.3790 4.8844 0.2880
#
#         policy_annual_premium_boxcox                                         \
#                                count      mean      min       25%       50%
# Cluster
# 0                           770.0000 1263.7603 485.1069 1099.2528 1262.4954
# 1                           230.0000 1246.6699 433.5870 1077.2753 1257.1486
#
#                                      total_claim_amount_boxcox              \
#               75%       max      std                     count        mean
# Cluster
# 0       1415.9520 2054.3488 245.0094                  770.0000 136628.8486
# 1       1426.4102 1833.1853 245.7449                  230.0000  22250.2362
#
#                                                                                \
#                min         25%         50%         75%         max        std
# Cluster
# 0       79806.9351 111977.9154 132568.3983 158580.2560 251198.4930 32479.0720
# 1         129.5888   8009.2486  10660.4658  15918.1902  78397.6808 24246.8323
#
#         injury_claim_cube                                            \
#                     count       mean         min         25%    50%
# Cluster
# 0                770.0000 -1266.9403 -32768.0000 -17312.0000 0.0000
# 1                230.0000 -1160.5217 -32768.0000 -19008.0000 0.0000
#
#                                          property_claim_cube            \
#                75%        max        std               count      mean
# Cluster
# 0       14122.0000 32704.0000 18662.4546            770.0000 -708.1247
# 1       14198.0000 32320.0000 19223.1651            230.0000   10.7826
#
#                                                                          \
#                 min         25%    50%        75%        max        std
# Cluster
# 0       -32768.0000 -15960.0000 0.0000 15082.0000 32704.0000 18835.1002
# 1       -32768.0000 -14848.0000 0.0000 13976.0000 32704.0000 18738.0789
#
#         vehicle_claim_boxcox                                                \
#                        count        mean        min        25%         50%
# Cluster
# 0                   770.0000 109849.6889 55635.1238 90256.0718 107863.5775
# 1                   230.0000  18216.8626    92.3253  6271.1018   8345.4865
#
#                                            insurance_age                 \
#                 75%         max        std         count    mean    min
# Cluster
# 0       126609.0517 195682.7153 26273.1504      770.0000 13.2831 0.0000
# 1        12276.8135  85829.3124 20765.3973      230.0000 13.7739 0.0000
#
#                                               vehicle_age                \
#            25%     50%     75%     max    std       count   mean    min
# Cluster
# 0       7.0000 13.0000 20.0000 25.0000 7.3658    770.0000 9.9974 0.0000
# 1       8.0000 14.0000 20.0000 25.0000 7.3456    230.0000 9.5609 0.0000
#
#                                               policy_state__IL                \
#            25%     50%     75%     max    std            count   mean    min
# Cluster
# 0       5.0000 10.0000 15.0000 20.0000 6.0516         770.0000 0.3377 0.0000
# 1       5.0000 10.0000 14.0000 20.0000 5.8952         230.0000 0.3391 0.0000
#
#                                            policy_state__IN                \
#            25%    50%    75%    max    std            count   mean    min
# Cluster
# 0       0.0000 0.0000 1.0000 1.0000 0.4732         770.0000 0.3091 0.0000
# 1       0.0000 0.0000 1.0000 1.0000 0.4744         230.0000 0.3130 0.0000
#
#                                            policy_state__OH                \
#            25%    50%    75%    max    std            count   mean    min
# Cluster
# 0       0.0000 0.0000 1.0000 1.0000 0.4624         770.0000 0.3532 0.0000
# 1       0.0000 0.0000 1.0000 1.0000 0.4647         230.0000 0.3478 0.0000
#
#                                            insured_hobbies__base-jumping  \
#            25%    50%    75%    max    std                         count
# Cluster
# 0       0.0000 0.0000 1.0000 1.0000 0.4783                      770.0000
# 1       0.0000 0.0000 1.0000 1.0000 0.4773                      230.0000
#
#                                                           \
#           mean    min    25%    50%    75%    max    std
# Cluster
# 0       0.0455 0.0000 0.0000 0.0000 0.0000 1.0000 0.2084
# 1       0.0609 0.0000 0.0000 0.0000 0.0000 1.0000 0.2396
#
#         insured_hobbies__basketball                                            \
#                               count   mean    min    25%    50%    75%    max
# Cluster
# 0                          770.0000 0.0390 0.0000 0.0000 0.0000 0.0000 1.0000
# 1                          230.0000 0.0174 0.0000 0.0000 0.0000 0.0000 1.0000
#
#                insured_hobbies__board-games                              \
#            std                        count   mean    min    25%    50%
# Cluster
# 0       0.1936                     770.0000 0.0494 0.0000 0.0000 0.0000
# 1       0.1310                     230.0000 0.0435 0.0000 0.0000 0.0000
#
#                              insured_hobbies__bungie-jumping                \
#            75%    max    std                           count   mean    min
# Cluster
# 0       0.0000 1.0000 0.2167                        770.0000 0.0545 0.0000
# 1       0.0000 1.0000 0.2044                        230.0000 0.0609 0.0000
#
#                                            insured_hobbies__camping         \
#            25%    50%    75%    max    std                    count   mean
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2272                 770.0000 0.0584
# 1       0.0000 0.0000 0.0000 1.0000 0.2396                 230.0000 0.0435
#
#                                                   insured_hobbies__chess  \
#            min    25%    50%    75%    max    std                  count
# Cluster
# 0       0.0000 0.0000 0.0000 0.0000 1.0000 0.2347               770.0000
# 1       0.0000 0.0000 0.0000 0.0000 1.0000 0.2044               230.0000
#
#                                                           \
#           mean    min    25%    50%    75%    max    std
# Cluster
# 0       0.0481 0.0000 0.0000 0.0000 0.0000 1.0000 0.2140
# 1       0.0391 0.0000 0.0000 0.0000 0.0000 1.0000 0.1943
#
#         insured_hobbies__cross-fit                                            \
#                              count   mean    min    25%    50%    75%    max
# Cluster
# 0                         770.0000 0.0416 0.0000 0.0000 0.0000 0.0000 1.0000
# 1                         230.0000 0.0130 0.0000 0.0000 0.0000 0.0000 1.0000
#
#                insured_hobbies__dancing                                     \
#            std                    count   mean    min    25%    50%    75%
# Cluster
# 0       0.1997                 770.0000 0.0403 0.0000 0.0000 0.0000 0.0000
# 1       0.1137                 230.0000 0.0522 0.0000 0.0000 0.0000 0.0000
#
#                       insured_hobbies__exercise                              \
#            max    std                     count   mean    min    25%    50%
# Cluster
# 0       1.0000 0.1967                  770.0000 0.0584 0.0000 0.0000 0.0000
# 1       1.0000 0.2229                  230.0000 0.0522 0.0000 0.0000 0.0000
#
#                              insured_hobbies__golf                       \
#            75%    max    std                 count   mean    min    25%
# Cluster
# 0       0.0000 1.0000 0.2347              770.0000 0.0506 0.0000 0.0000
# 1       0.0000 1.0000 0.2229              230.0000 0.0696 0.0000 0.0000
#
#                                     insured_hobbies__hiking                \
#            50%    75%    max    std                   count   mean    min
# Cluster
# 0       0.0000 0.0000 1.0000 0.2194                770.0000 0.0597 0.0000
# 1       0.0000 0.0000 1.0000 0.2550                230.0000 0.0261 0.0000
#
#                                            insured_hobbies__kayaking         \
#            25%    50%    75%    max    std                     count   mean
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2372                  770.0000 0.0532
# 1       0.0000 0.0000 0.0000 1.0000 0.1597                  230.0000 0.0565
#
#                                                   insured_hobbies__movies  \
#            min    25%    50%    75%    max    std                   count
# Cluster
# 0       0.0000 0.0000 0.0000 0.0000 1.0000 0.2247                770.0000
# 1       0.0000 0.0000 0.0000 0.0000 1.0000 0.2314                230.0000
#
#                                                           \
#           mean    min    25%    50%    75%    max    std
# Cluster
# 0       0.0494 0.0000 0.0000 0.0000 0.0000 1.0000 0.2167
# 1       0.0739 0.0000 0.0000 0.0000 0.0000 1.0000 0.2622
#
#         insured_hobbies__paintball                                            \
#                              count   mean    min    25%    50%    75%    max
# Cluster
# 0                         770.0000 0.0519 0.0000 0.0000 0.0000 0.0000 1.0000
# 1                         230.0000 0.0739 0.0000 0.0000 0.0000 0.0000 1.0000
#
#                insured_hobbies__polo                                     \
#            std                 count   mean    min    25%    50%    75%
# Cluster
# 0       0.2221              770.0000 0.0442 0.0000 0.0000 0.0000 0.0000
# 1       0.2622              230.0000 0.0565 0.0000 0.0000 0.0000 0.0000
#
#                       insured_hobbies__reading                              \
#            max    std                    count   mean    min    25%    50%
# Cluster
# 0       1.0000 0.2056                 770.0000 0.0610 0.0000 0.0000 0.0000
# 1       1.0000 0.2314                 230.0000 0.0739 0.0000 0.0000 0.0000
#
#                              insured_hobbies__skydiving                       \
#            75%    max    std                      count   mean    min    25%
# Cluster
# 0       0.0000 1.0000 0.2396                   770.0000 0.0494 0.0000 0.0000
# 1       0.0000 1.0000 0.2622                   230.0000 0.0478 0.0000 0.0000
#
#                                     insured_hobbies__sleeping                \
#            50%    75%    max    std                     count   mean    min
# Cluster
# 0       0.0000 0.0000 1.0000 0.2167                  770.0000 0.0455 0.0000
# 1       0.0000 0.0000 1.0000 0.2139                  230.0000 0.0261 0.0000
#
#                                            insured_hobbies__video-games  \
#            25%    50%    75%    max    std                        count
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2084                     770.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.1597                     230.0000
#
#                                                           \
#           mean    min    25%    50%    75%    max    std
# Cluster
# 0       0.0481 0.0000 0.0000 0.0000 0.0000 1.0000 0.2140
# 1       0.0565 0.0000 0.0000 0.0000 0.0000 1.0000 0.2314
#
#         insured_hobbies__yachting                                            \
#                             count   mean    min    25%    50%    75%    max
# Cluster
# 0                        770.0000 0.0519 0.0000 0.0000 0.0000 0.0000 1.0000
# 1                        230.0000 0.0565 0.0000 0.0000 0.0000 0.0000 1.0000
#
#                insured_occ__adm-clerical                                     \
#            std                     count   mean    min    25%    50%    75%
# Cluster
# 0       0.2221                  770.0000 0.0571 0.0000 0.0000 0.0000 0.0000
# 1       0.2314                  230.0000 0.0913 0.0000 0.0000 0.0000 0.0000
#
#                       insured_occ__armed-forces                              \
#            max    std                     count   mean    min    25%    50%
# Cluster
# 0       1.0000 0.2323                  770.0000 0.0714 0.0000 0.0000 0.0000
# 1       1.0000 0.2887                  230.0000 0.0609 0.0000 0.0000 0.0000
#
#                              insured_occ__craft-repair                       \
#            75%    max    std                     count   mean    min    25%
# Cluster
# 0       0.0000 1.0000 0.2577                  770.0000 0.0766 0.0000 0.0000
# 1       0.0000 1.0000 0.2396                  230.0000 0.0652 0.0000 0.0000
#
#                                     insured_occ__exec-managerial         \
#            50%    75%    max    std                        count   mean
# Cluster
# 0       0.0000 0.0000 1.0000 0.2662                     770.0000 0.0792
# 1       0.0000 0.0000 1.0000 0.2474                     230.0000 0.0652
#
#                                                    \
#            min    25%    50%    75%    max    std
# Cluster
# 0       0.0000 0.0000 0.0000 0.0000 1.0000 0.2703
# 1       0.0000 0.0000 0.0000 0.0000 1.0000 0.2474
#
#         insured_occ__farming-fishing                                     \
#                                count   mean    min    25%    50%    75%
# Cluster
# 0                           770.0000 0.0519 0.0000 0.0000 0.0000 0.0000
# 1                           230.0000 0.0565 0.0000 0.0000 0.0000 0.0000
#
#                       insured_occ__handlers-cleaners                       \
#            max    std                          count   mean    min    25%
# Cluster
# 0       1.0000 0.2221                       770.0000 0.0610 0.0000 0.0000
# 1       1.0000 0.2314                       230.0000 0.0304 0.0000 0.0000
#
#                                     insured_occ__machine-op-inspct         \
#            50%    75%    max    std                          count   mean
# Cluster
# 0       0.0000 0.0000 1.0000 0.2396                       770.0000 0.0961
# 1       0.0000 0.0000 1.0000 0.1722                       230.0000 0.0826
#
#                                                   insured_occ__other-service  \
#            min    25%    50%    75%    max    std                      count
# Cluster
# 0       0.0000 0.0000 0.0000 0.0000 1.0000 0.2949                   770.0000
# 1       0.0000 0.0000 0.0000 0.0000 1.0000 0.2759                   230.0000
#
#                                                           \
#           mean    min    25%    50%    75%    max    std
# Cluster
# 0       0.0662 0.0000 0.0000 0.0000 0.0000 1.0000 0.2489
# 1       0.0870 0.0000 0.0000 0.0000 0.0000 1.0000 0.2824
#
#         insured_occ__priv-house-serv                                     \
#                                count   mean    min    25%    50%    75%
# Cluster
# 0                           770.0000 0.0727 0.0000 0.0000 0.0000 0.0000
# 1                           230.0000 0.0652 0.0000 0.0000 0.0000 0.0000
#
#                       insured_occ__prof-specialty                              \
#            max    std                       count   mean    min    25%    50%
# Cluster
# 0       1.0000 0.2599                    770.0000 0.0831 0.0000 0.0000 0.0000
# 1       1.0000 0.2474                    230.0000 0.0913 0.0000 0.0000 0.0000
#
#                              insured_occ__protective-serv                \
#            75%    max    std                        count   mean    min
# Cluster
# 0       0.0000 1.0000 0.2762                     770.0000 0.0649 0.0000
# 1       0.0000 1.0000 0.2887                     230.0000 0.0565 0.0000
#
#                                            insured_occ__sales                \
#            25%    50%    75%    max    std              count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2466           770.0000 0.0662 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2314           230.0000 0.1087 0.0000
#
#                                            insured_occ__tech-support         \
#            25%    50%    75%    max    std                     count   mean
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2489                  770.0000 0.0779
# 1       0.0000 0.0000 0.0000 1.0000 0.3119                  230.0000 0.0783
#
#                                                    \
#            min    25%    50%    75%    max    std
# Cluster
# 0       0.0000 0.0000 0.0000 0.0000 1.0000 0.2682
# 1       0.0000 0.0000 0.0000 0.0000 1.0000 0.2692
#
#         insured_occ__transport-moving                                     \
#                                 count   mean    min    25%    50%    75%
# Cluster
# 0                            770.0000 0.0753 0.0000 0.0000 0.0000 0.0000
# 1                            230.0000 0.0609 0.0000 0.0000 0.0000 0.0000
#
#                       insured_rela__husband                              \
#            max    std                 count   mean    min    25%    50%
# Cluster
# 0       1.0000 0.2641              770.0000 0.1727 0.0000 0.0000 0.0000
# 1       1.0000 0.2396              230.0000 0.1609 0.0000 0.0000 0.0000
#
#                              insured_rela__not-in-family                       \
#            75%    max    std                       count   mean    min    25%
# Cluster
# 0       0.0000 1.0000 0.3783                    770.0000 0.1766 0.0000 0.0000
# 1       0.0000 1.0000 0.3682                    230.0000 0.1652 0.0000 0.0000
#
#                                     insured_rela__other-relative         \
#            50%    75%    max    std                        count   mean
# Cluster
# 0       0.0000 0.0000 1.0000 0.3816                     770.0000 0.1740
# 1       0.0000 0.0000 1.0000 0.3722                     230.0000 0.1870
#
#                                                   insured_rela__own-child  \
#            min    25%    50%    75%    max    std                   count
# Cluster
# 0       0.0000 0.0000 0.0000 0.0000 1.0000 0.3794                770.0000
# 1       0.0000 0.0000 0.0000 0.0000 1.0000 0.3907                230.0000
#
#                                                           \
#           mean    min    25%    50%    75%    max    std
# Cluster
# 0       0.1805 0.0000 0.0000 0.0000 0.0000 1.0000 0.3849
# 1       0.1913 0.0000 0.0000 0.0000 0.0000 1.0000 0.3942
#
#         insured_rela__unmarried                                            \
#                           count   mean    min    25%    50%    75%    max
# Cluster
# 0                      770.0000 0.1416 0.0000 0.0000 0.0000 0.0000 1.0000
# 1                      230.0000 0.1391 0.0000 0.0000 0.0000 0.0000 1.0000
#
#                insured_rela__wife                                            \
#            std              count   mean    min    25%    50%    75%    max
# Cluster
# 0       0.3488           770.0000 0.1545 0.0000 0.0000 0.0000 0.0000 1.0000
# 1       0.3468           230.0000 0.1565 0.0000 0.0000 0.0000 0.0000 1.0000
#
#                incident_type__Multi-vehicle Collision                       \
#            std                                  count   mean    min    25%
# Cluster
# 0       0.3617                               770.0000 0.5013 0.0000 0.0000
# 1       0.3641                               230.0000 0.1435 0.0000 0.0000
#
#                                     incident_type__Parked Car                \
#            50%    75%    max    std                     count   mean    min
# Cluster
# 0       1.0000 1.0000 1.0000 0.5003                  770.0000 0.0000 0.0000
# 1       0.0000 0.0000 1.0000 0.3513                  230.0000 0.3652 0.0000
#
#                                             \
#            25%    50%    75%    max    std
# Cluster
# 0       0.0000 0.0000 0.0000 0.0000 0.0000
# 1       0.0000 0.0000 1.0000 1.0000 0.4825
#
#         incident_type__Single Vehicle Collision                              \
#                                           count   mean    min    25%    50%
# Cluster
# 0                                      770.0000 0.4987 0.0000 0.0000 0.0000
# 1                                      230.0000 0.0826 0.0000 0.0000 0.0000
#
#                              incident_type__Vehicle Theft                \
#            75%    max    std                        count   mean    min
# Cluster
# 0       1.0000 1.0000 0.5003                     770.0000 0.0000 0.0000
# 1       0.0000 1.0000 0.2759                     230.0000 0.4087 0.0000
#
#                                            collision_type__Front Collision  \
#            25%    50%    75%    max    std                           count
# Cluster
# 0       0.0000 0.0000 0.0000 0.0000 0.0000                        770.0000
# 1       0.0000 0.0000 1.0000 1.0000 0.4927                        230.0000
#
#                                                           \
#           mean    min    25%    50%    75%    max    std
# Cluster
# 0       0.3091 0.0000 0.0000 0.0000 1.0000 1.0000 0.4624
# 1       0.0696 0.0000 0.0000 0.0000 0.0000 1.0000 0.2550
#
#         collision_type__Others                                            \
#                          count   mean    min    25%    50%    75%    max
# Cluster
# 0                     770.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
# 1                     230.0000 0.7739 0.0000 1.0000 1.0000 1.0000 1.0000
#
#                collision_type__Rear Collision                              \
#            std                          count   mean    min    25%    50%
# Cluster
# 0       0.0000                       770.0000 0.3571 0.0000 0.0000 0.0000
# 1       0.4192                       230.0000 0.0739 0.0000 0.0000 0.0000
#
#                              collision_type__Side Collision                \
#            75%    max    std                          count   mean    min
# Cluster
# 0       1.0000 1.0000 0.4795                       770.0000 0.3338 0.0000
# 1       0.0000 1.0000 0.2622                       230.0000 0.0826 0.0000
#
#                                            authorities_contacted__Ambulance  \
#            25%    50%    75%    max    std                            count
# Cluster
# 0       0.0000 0.0000 1.0000 1.0000 0.4719                         770.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2759                         230.0000
#
#                                                           \
#           mean    min    25%    50%    75%    max    std
# Cluster
# 0       0.2351 0.0000 0.0000 0.0000 0.0000 1.0000 0.4243
# 1       0.1130 0.0000 0.0000 0.0000 0.0000 1.0000 0.3173
#
#         authorities_contacted__Fire                                            \
#                               count   mean    min    25%    50%    75%    max
# Cluster
# 0                          770.0000 0.2701 0.0000 0.0000 0.0000 1.0000 1.0000
# 1                          230.0000 0.0652 0.0000 0.0000 0.0000 0.0000 1.0000
#
#                authorities_contacted__Other                              \
#            std                        count   mean    min    25%    50%
# Cluster
# 0       0.4443                     770.0000 0.2506 0.0000 0.0000 0.0000
# 1       0.2474                     230.0000 0.2478 0.0000 0.0000 0.0000
#
#                              authorities_contacted__Police                \
#            75%    max    std                         count   mean    min
# Cluster
# 0       0.7500 1.0000 0.4337                      770.0000 0.2442 0.0000
# 1       0.0000 1.0000 0.4327                      230.0000 0.5739 0.0000
#
#                                            incident_state__NC                \
#            25%    50%    75%    max    std              count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.4299           770.0000 0.1026 0.0000
# 1       0.0000 1.0000 1.0000 1.0000 0.4956           230.0000 0.1348 0.0000
#
#                                            incident_state__NY                \
#            25%    50%    75%    max    std              count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.3036           770.0000 0.2831 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.3422           230.0000 0.1913 0.0000
#
#                                            incident_state__OH                \
#            25%    50%    75%    max    std              count   mean    min
# Cluster
# 0       0.0000 0.0000 1.0000 1.0000 0.4508           770.0000 0.0234 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.3942           230.0000 0.0217 0.0000
#
#                                            incident_state__PA                \
#            25%    50%    75%    max    std              count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.1512           770.0000 0.0299 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.1461           230.0000 0.0304 0.0000
#
#                                            incident_state__SC                \
#            25%    50%    75%    max    std              count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.1703           770.0000 0.2558 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.1722           230.0000 0.2217 0.0000
#
#                                            incident_state__VA                \
#            25%    50%    75%    max    std              count   mean    min
# Cluster
# 0       0.0000 0.0000 1.0000 1.0000 0.4366           770.0000 0.1039 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.4163           230.0000 0.1304 0.0000
#
#                                            incident_state__WV                \
#            25%    50%    75%    max    std              count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.3053           770.0000 0.2013 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.3375           230.0000 0.2696 0.0000
#
#                                            incident_city__Arlington         \
#            25%    50%    75%    max    std                    count   mean
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.4012                 770.0000 0.1416
# 1       0.0000 0.0000 1.0000 1.0000 0.4447                 230.0000 0.1870
#
#                                                   incident_city__Columbus  \
#            min    25%    50%    75%    max    std                   count
# Cluster
# 0       0.0000 0.0000 0.0000 0.0000 1.0000 0.3488                770.0000
# 1       0.0000 0.0000 0.0000 0.0000 1.0000 0.3907                230.0000
#
#                                                           \
#           mean    min    25%    50%    75%    max    std
# Cluster
# 0       0.1623 0.0000 0.0000 0.0000 0.0000 1.0000 0.3690
# 1       0.1043 0.0000 0.0000 0.0000 0.0000 1.0000 0.3064
#
#         incident_city__Hillsdale                                            \
#                            count   mean    min    25%    50%    75%    max
# Cluster
# 0                       770.0000 0.1429 0.0000 0.0000 0.0000 0.0000 1.0000
# 1                       230.0000 0.1348 0.0000 0.0000 0.0000 0.0000 1.0000
#
#                incident_city__Northbend                                     \
#            std                    count   mean    min    25%    50%    75%
# Cluster
# 0       0.3502                 770.0000 0.1481 0.0000 0.0000 0.0000 0.0000
# 1       0.3422                 230.0000 0.1348 0.0000 0.0000 0.0000 0.0000
#
#                       incident_city__Northbrook                              \
#            max    std                     count   mean    min    25%    50%
# Cluster
# 0       1.0000 0.3554                  770.0000 0.1182 0.0000 0.0000 0.0000
# 1       1.0000 0.3422                  230.0000 0.1348 0.0000 0.0000 0.0000
#
#                              incident_city__Riverwood                       \
#            75%    max    std                    count   mean    min    25%
# Cluster
# 0       0.0000 1.0000 0.3230                 770.0000 0.1299 0.0000 0.0000
# 1       0.0000 1.0000 0.3422                 230.0000 0.1478 0.0000 0.0000
#
#                                     incident_city__Springfield                \
#            50%    75%    max    std                      count   mean    min
# Cluster
# 0       0.0000 0.0000 1.0000 0.3364                   770.0000 0.1571 0.0000
# 1       0.0000 0.0000 1.0000 0.3557                   230.0000 0.1565 0.0000
#
#                                            auto_make__Accura                \
#            25%    50%    75%    max    std             count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.3642          770.0000 0.0701 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.3641          230.0000 0.0609 0.0000
#
#                                            auto_make__Audi                \
#            25%    50%    75%    max    std           count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2555        770.0000 0.0688 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2396        230.0000 0.0696 0.0000
#
#                                            auto_make__BMW                \
#            25%    50%    75%    max    std          count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2533       770.0000 0.0727 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2550       230.0000 0.0696 0.0000
#
#                                            auto_make__Chevrolet                \
#            25%    50%    75%    max    std                count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2599             770.0000 0.0740 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2550             230.0000 0.0826 0.0000
#
#                                            auto_make__Dodge                \
#            25%    50%    75%    max    std            count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2620         770.0000 0.0818 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2759         230.0000 0.0739 0.0000
#
#                                            auto_make__Ford                \
#            25%    50%    75%    max    std           count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2743        770.0000 0.0740 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2622        230.0000 0.0652 0.0000
#
#                                            auto_make__Honda                \
#            25%    50%    75%    max    std            count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2620         770.0000 0.0545 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2474         230.0000 0.0565 0.0000
#
#                                            auto_make__Jeep                \
#            25%    50%    75%    max    std           count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2272        770.0000 0.0636 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2314        230.0000 0.0783 0.0000
#
#                                            auto_make__Mercedes                \
#            25%    50%    75%    max    std               count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2443            770.0000 0.0636 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2692            230.0000 0.0696 0.0000
#
#                                            auto_make__Nissan                \
#            25%    50%    75%    max    std             count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2443          770.0000 0.0818 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2550          230.0000 0.0652 0.0000
#
#                                            auto_make__Saab                \
#            25%    50%    75%    max    std           count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2743        770.0000 0.0831 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2474        230.0000 0.0696 0.0000
#
#                                            auto_make__Suburu                \
#            25%    50%    75%    max    std             count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2762          770.0000 0.0857 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2550          230.0000 0.0609 0.0000
#
#                                            auto_make__Toyota                \
#            25%    50%    75%    max    std             count   mean    min
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2801          770.0000 0.0623 0.0000
# 1       0.0000 0.0000 0.0000 1.0000 0.2396          230.0000 0.0957 0.0000
#
#                                            auto_make__Volkswagen         \
#            25%    50%    75%    max    std                 count   mean
# Cluster
# 0       0.0000 0.0000 0.0000 1.0000 0.2419              770.0000 0.0636
# 1       0.0000 0.0000 0.0000 1.0000 0.2948              230.0000 0.0826
#
#
#            min    25%    50%    75%    max    std
# Cluster
# 0       0.0000 0.0000 0.0000 0.0000 1.0000 0.2443
# 1       0.0000 0.0000 0.0000 0.0000 1.0000 0.2759

# %%
# Select categorical columns
cat_cols = df.select_dtypes(exclude='number').columns


# Calculate number of rows needed
num_plots = len(cat_cols)
num_rows = int(np.ceil(num_plots / 3))

# Create subplots with appropriate figsize
fig, axes = plt.subplots(ncols=3, nrows=num_rows, figsize=(20, num_rows * 5))
axes = axes.flatten()

# Plot each numeric column
for i, col in enumerate(cat_cols):
    sns.barplot(data=df, y=col, x='Cluster',  ax=axes[i],hue='fraud_reported',hue_order=[0,1],legend=False,palette=['DarkGreen','maroon'])
    axes[i].set_title(col, fontdict={'fontsize': 20, 'fontweight': 'bold'})
    axes[i].tick_params(axis='x', rotation=25, labelsize=20)
    axes[i].tick_params(axis='y', labelsize=20)
    axes[i].set_xlabel(col, fontsize=20, weight='bold')
    axes[i].set_ylabel('Count', fontsize=20, weight='bold')

# Turn off any unused subplots
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# Select numeric columns, excluding 'Cluster'
numeric_columns = df.select_dtypes(include='number').columns

if 'Cluster' in numeric_columns:
    numeric_columns = numeric_columns.drop('Cluster')

# Calculate number of rows needed
num_plots = len(numeric_columns)
num_rows = int(np.ceil(num_plots / 3))

# Create subplots with appropriate figsize
fig, axes = plt.subplots(ncols=3, nrows=num_rows, figsize=(20, num_rows * 5))
axes = axes.flatten()

# Plot each numeric column
for i, col in enumerate(numeric_columns):
    sns.boxplot(x='Cluster', y=col, data=df,hue='fraud_reported',hue_order=[0,1],legend=False,palette=['DarkGreen','maroon'] ,ax=axes[i])
    axes[i].set_title(col, fontdict={'fontsize': 20, 'fontweight': 'bold'})
    axes[i].tick_params(axis='x', rotation=25, labelsize=20)
    axes[i].tick_params(axis='y', labelsize=20)
    axes[i].set_xlabel(col, fontsize=20, weight='bold')
    axes[i].set_ylabel('Count', fontsize=20, weight='bold')

# Turn off any unused subplots
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# Define significance thresholds
extreme_threshold = 0.001
moderate_threshold = 0.05

# Iterate through each feature
for feature in df1.select_dtypes(exclude=['datetime64[ns]']).columns:
    # Get the data for each cluster
    cluster0 = df1[df1['Cluster'] == 0][feature]
    cluster1 = df1[df1['Cluster'] == 1][feature]
    
    # Perform the t-test
    t_stat, p_value = ttest_ind(cluster0, cluster1)
    
    # Determine the significance level
    if p_value <= extreme_threshold:
        color = 'green'
        significance = 'Extreme Significance'
    elif p_value <= moderate_threshold:
        color = 'magenta'
        significance = 'Moderate Significance'
    else:
        color = 'red'
        significance = 'No Significance'
    
    # Print the results with color coding
    print(colored(f'{feature}: t-stat={t_stat:.4f}, p-value={p_value:.4f} ({significance})', color))
# Out:
# months_as_customer: t-stat=0.9637, p-value=0.3354 (No Significance)
# policy_deductable: t-stat=0.5254, p-value=0.5994 (No Significance)
# insured_sex: t-stat=0.5255, p-value=0.5994 (No Significance)
# insured_education_level: t-stat=1.9378, p-value=0.0529 (No Significance)
# incident_severity: t-stat=-12.2283, p-value=0.0000 (Extreme Significance)
# incident_hour_of_the_day: t-stat=7.0067, p-value=0.0000 (Extreme Significance)
# number_of_vehicles_involved: t-stat=9.5465, p-value=0.0000 (Extreme Significance)
# property_damage: t-stat=1.0507, p-value=0.2936 (No Significance)
# bodily_injuries: t-stat=0.6558, p-value=0.5121 (No Significance)
# witnesses: t-stat=-0.4724, p-value=0.6367 (No Significance)
# police_report_available: t-stat=-1.7997, p-value=0.0722 (No Significance)
# auto_year: t-stat=-0.9656, p-value=0.3345 (No Significance)
# fraud_reported: t-stat=5.4419, p-value=0.0000 (Extreme Significance)
# age_boxcox: t-stat=1.0522, p-value=0.2930 (No Significance)
# policy_annual_premium_boxcox: t-stat=0.9276, p-value=0.3538 (No Significance)
# total_claim_amount_boxcox: t-stat=49.4436, p-value=0.0000 (Extreme Significance)
# injury_claim_cube: t-stat=-0.0754, p-value=0.9399 (No Significance)
# property_claim_cube: t-stat=-0.5085, p-value=0.6112 (No Significance)
# vehicle_claim_boxcox: t-stat=48.5516, p-value=0.0000 (Extreme Significance)
# insurance_age: t-stat=-0.8873, p-value=0.3751 (No Significance)
# vehicle_age: t-stat=0.9656, p-value=0.3345 (No Significance)
# policy_state__IL: t-stat=-0.0413, p-value=0.9671 (No Significance)
# policy_state__IN: t-stat=-0.1136, p-value=0.9096 (No Significance)
# policy_state__OH: t-stat=0.1509, p-value=0.8801 (No Significance)
# insured_hobbies__base-jumping: t-stat=-0.9498, p-value=0.3425 (No Significance)
# insured_hobbies__basketball: t-stat=1.5843, p-value=0.1134 (No Significance)
# insured_hobbies__board-games: t-stat=0.3652, p-value=0.7150 (No Significance)
# insured_hobbies__bungie-jumping: t-stat=-0.3657, p-value=0.7147 (No Significance)
# insured_hobbies__camping: t-stat=0.8729, p-value=0.3829 (No Significance)
# insured_hobbies__chess: t-stat=0.5663, p-value=0.5713 (No Significance)
# insured_hobbies__cross-fit: t-stat=2.0672, p-value=0.0390 (Moderate Significance)
# insured_hobbies__dancing: t-stat=-0.7811, p-value=0.4350 (No Significance)
# insured_hobbies__exercise: t-stat=0.3594, p-value=0.7193 (No Significance)
# insured_hobbies__golf: t-stat=-1.1037, p-value=0.2700 (No Significance)
# insured_hobbies__hiking: t-stat=2.0192, p-value=0.0437 (Moderate Significance)
# insured_hobbies__kayaking: t-stat=-0.1926, p-value=0.8473 (No Significance)
# insured_hobbies__movies: t-stat=-1.4338, p-value=0.1519 (No Significance)
# insured_hobbies__paintball: t-stat=-1.2605, p-value=0.2078 (No Significance)
# insured_hobbies__polo: t-stat=-0.7770, p-value=0.4373 (No Significance)
# insured_hobbies__reading: t-stat=-0.6995, p-value=0.4844 (No Significance)
# insured_hobbies__skydiving: t-stat=0.0939, p-value=0.9252 (No Significance)
# insured_hobbies__sleeping: t-stat=1.2996, p-value=0.1940 (No Significance)
# insured_hobbies__video-games: t-stat=-0.5167, p-value=0.6055 (No Significance)
# insured_hobbies__yachting: t-stat=-0.2714, p-value=0.7861 (No Significance)
# insured_occ__adm-clerical: t-stat=-1.8454, p-value=0.0653 (No Significance)
# insured_occ__armed-forces: t-stat=0.5539, p-value=0.5797 (No Significance)
# insured_occ__craft-repair: t-stat=0.5794, p-value=0.5625 (No Significance)
# insured_occ__exec-managerial: t-stat=0.7027, p-value=0.4824 (No Significance)
# insured_occ__farming-fishing: t-stat=-0.2714, p-value=0.7861 (No Significance)
# insured_occ__handlers-cleaners: t-stat=1.8031, p-value=0.0717 (No Significance)
# insured_occ__machine-op-inspct: t-stat=0.6179, p-value=0.5368 (No Significance)
# insured_occ__other-service: t-stat=-1.0733, p-value=0.2834 (No Significance)
# insured_occ__priv-house-serv: t-stat=0.3888, p-value=0.6975 (No Significance)
# insured_occ__prof-specialty: t-stat=-0.3903, p-value=0.6964 (No Significance)
# insured_occ__protective-serv: t-stat=0.4604, p-value=0.6453 (No Significance)
# insured_occ__sales: t-stat=-2.1351, p-value=0.0330 (Moderate Significance)
# insured_occ__tech-support: t-stat=-0.0168, p-value=0.9866 (No Significance)
# insured_occ__transport-moving: t-stat=0.7437, p-value=0.4573 (No Significance)
# insured_rela__husband: t-stat=0.4197, p-value=0.6748 (No Significance)
# insured_rela__not-in-family: t-stat=0.4000, p-value=0.6892 (No Significance)
# insured_rela__other-relative: t-stat=-0.4505, p-value=0.6525 (No Significance)
# insured_rela__own-child: t-stat=-0.3708, p-value=0.7108 (No Significance)
# insured_rela__unmarried: t-stat=0.0928, p-value=0.9261 (No Significance)
# insured_rela__wife: t-stat=-0.0726, p-value=0.9421 (No Significance)
# incident_type__Multi-vehicle Collision: t-stat=10.1245, p-value=0.0000 (Extreme Significance)
# incident_type__Parked Car: t-stat=-21.0268, p-value=0.0000 (Extreme Significance)
# incident_type__Single Vehicle Collision: t-stat=12.0734, p-value=0.0000 (Extreme Significance)
# incident_type__Vehicle Theft: t-stat=-23.0465, p-value=0.0000 (Extreme Significance)
# collision_type__Front Collision: t-stat=7.5198, p-value=0.0000 (Extreme Significance)
# collision_type__Others: t-stat=-51.2884, p-value=0.0000 (Extreme Significance)
# collision_type__Rear Collision: t-stat=8.5815, p-value=0.0000 (Extreme Significance)
# collision_type__Side Collision: t-stat=7.6876, p-value=0.0000 (Extreme Significance)
# authorities_contacted__Ambulance: t-stat=4.0365, p-value=0.0001 (Extreme Significance)
# authorities_contacted__Fire: t-stat=6.6897, p-value=0.0000 (Extreme Significance)
# authorities_contacted__Other: t-stat=0.0867, p-value=0.9309 (No Significance)
# authorities_contacted__Police: t-stat=-9.8438, p-value=0.0000 (Extreme Significance)
# incident_state__NC: t-stat=-1.3688, p-value=0.1714 (No Significance)
# incident_state__NY: t-stat=2.7866, p-value=0.0054 (Moderate Significance)
# incident_state__OH: t-stat=0.1452, p-value=0.8846 (No Significance)
# incident_state__PA: t-stat=-0.0440, p-value=0.9649 (No Significance)
# incident_state__SC: t-stat=1.0505, p-value=0.2937 (No Significance)
# incident_state__VA: t-stat=-1.1283, p-value=0.2594 (No Significance)
# incident_state__WV: t-stat=-2.2071, p-value=0.0275 (Moderate Significance)
# incident_city__Arlington: t-stat=-1.6835, p-value=0.0926 (No Significance)
# incident_city__Columbus: t-stat=2.1702, p-value=0.0302 (Moderate Significance)
# incident_city__Hillsdale: t-stat=0.3085, p-value=0.7578 (No Significance)
# incident_city__Northbend: t-stat=0.5011, p-value=0.6164 (No Significance)
# incident_city__Northbrook: t-stat=-0.6745, p-value=0.5002 (No Significance)
# incident_city__Riverwood: t-stat=-0.7009, p-value=0.4835 (No Significance)
# incident_city__Springfield: t-stat=0.0227, p-value=0.9819 (No Significance)
# auto_make__Accura: t-stat=0.4891, p-value=0.6249 (No Significance)
# auto_make__Audi: t-stat=-0.0385, p-value=0.9693 (No Significance)
# auto_make__BMW: t-stat=0.1626, p-value=0.8708 (No Significance)
# auto_make__Chevrolet: t-stat=-0.4306, p-value=0.6668 (No Significance)
# auto_make__Dodge: t-stat=0.3874, p-value=0.6985 (No Significance)
# auto_make__Ford: t-stat=0.4531, p-value=0.6506 (No Significance)
# auto_make__Honda: t-stat=-0.1152, p-value=0.9083 (No Significance)
# auto_make__Jeep: t-stat=-0.7779, p-value=0.4368 (No Significance)
# auto_make__Mercedes: t-stat=-0.3197, p-value=0.7492 (No Significance)
# auto_make__Nissan: t-stat=0.8233, p-value=0.4106 (No Significance)
# auto_make__Saab: t-stat=0.6642, p-value=0.5067 (No Significance)
# auto_make__Suburu: t-stat=1.2184, p-value=0.2234 (No Significance)
# auto_make__Toyota: t-stat=-1.7385, p-value=0.0824 (No Significance)
# auto_make__Volkswagen: t-stat=-1.0024, p-value=0.3164 (No Significance)
# Cluster: t-stat=-inf, p-value=0.0000 (Extreme Significance)
# /run/media/E_Drive/Technology/Python Project/Capstone/Insurance_Analytics_Prediction/insurance/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:573: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
from sklearn.manifold import TSNE

cluster_0_color = 'maroon'  
cluster_1_color = 'darkblue' 

# Ensure continuous_features only contains numerical columns
continuous_features = df.select_dtypes(include=['int', 'float']).columns.tolist()
categorical_features = df.select_dtypes(include=['category', 'object']).columns.tolist()

# PCA for feature importance
pca = PCA()
pca_result = pca.fit_transform(df[continuous_features])

# Plot cumulative explained variance ratio
plt.figure(figsize=(10, 6))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA Cumulative Explained Variance')
plt.show()

# t-SNE for visualization
tsne = TSNE(n_components=2, random_state=42)
tsne_result = tsne.fit_transform(df[continuous_features])

plt.figure(figsize=(10, 6))
plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=df['Cluster'], cmap='viridis')
plt.colorbar(label='Cluster')
plt.title('t-SNE visualization of clusters')
plt.show()

# Analyze cluster characteristics
cluster_0 = df[df['Cluster'] == 0]
cluster_1 = df[df['Cluster'] == 1]

print("Cluster 0 mean values:")
print(cluster_0[continuous_features].mean())
print("\nCluster 1 mean values:")
print(cluster_1[continuous_features].mean())

# For categorical features, look at the most common values in each cluster
for feature in categorical_features:
    print(f"\nMost common {feature} in Cluster 0:", cluster_0[feature].value_counts().index[0])
    print(f"Most common {feature} in Cluster 1:", cluster_1[feature].value_counts().index[0])

# Additional analysis: distribution of categorical variables
for feature in categorical_features:
    plt.figure(figsize=(12, 6))
    cluster_0[feature].value_counts(normalize=True).plot(kind='bar',color=cluster_0_color, alpha=0.5, label='Cluster 0')
    cluster_1[feature].value_counts(normalize=True).plot(kind='bar',color=cluster_1_color, alpha=0.5, label='Cluster 1')
    plt.title(f'Distribution of {feature} in Clusters')
    plt.legend()
    plt.show()
# Out:
# Cluster 0 mean values:
# age_boxcox                          4.1899
# policy_annual_premium_boxcox     1263.7603
# total_claim_amount_boxcox      136628.8486
# vehicle_claim_boxcox           109849.6889
# Cluster                             0.0000
# dtype: float64
#
# Cluster 1 mean values:
# age_boxcox                         4.1655
# policy_annual_premium_boxcox    1246.6699
# total_claim_amount_boxcox      22250.2362
# vehicle_claim_boxcox           18216.8626
# Cluster                            1.0000
# dtype: float64
#
# Most common policy_state in Cluster 0: OH
# Most common policy_state in Cluster 1: OH
#
# Most common insured_occupation in Cluster 0: machine-op-inspct
# Most common insured_occupation in Cluster 1: sales
#
# Most common insured_hobbies in Cluster 0: reading
# Most common insured_hobbies in Cluster 1: reading
#
# Most common insured_relationship in Cluster 0: own-child
# Most common insured_relationship in Cluster 1: own-child
#
# Most common incident_type in Cluster 0: Multi-vehicle Collision
# Most common incident_type in Cluster 1: Vehicle Theft
#
# Most common collision_type in Cluster 0: Rear Collision
# Most common collision_type in Cluster 1: Others
#
# Most common authorities_contacted in Cluster 0: Fire
# Most common authorities_contacted in Cluster 1: Police
#
# Most common incident_state in Cluster 0: NY
# Most common incident_state in Cluster 1: WV
#
# Most common incident_city in Cluster 0: Columbus
# Most common incident_city in Cluster 1: Arlington
#
# Most common incident_hour_of_the_day in Cluster 0: 23
# Most common incident_hour_of_the_day in Cluster 1: 3
#
# Most common number_of_vehicles_involved in Cluster 0: 1
# Most common number_of_vehicles_involved in Cluster 1: 1
#
# Most common bodily_injuries in Cluster 0: 2
# Most common bodily_injuries in Cluster 1: 1
#
# Most common witnesses in Cluster 0: 0
# Most common witnesses in Cluster 1: 1
#
# Most common auto_make in Cluster 0: Suburu
# Most common auto_make in Cluster 1: Toyota
#
# Most common auto_year in Cluster 0: 1995
# Most common auto_year in Cluster 1: 2013

# %% [markdown]
# ## <span style="color:Aqua;">Categorical Encoded detail:</span>

# %% [markdown]
# Credit_Mix_map = { 'Poor': 0,'Bad':0, 'Standard':1, 'Good': 2  }
# Payment_of_Min_Amount_map = { 'No':0, 'Nm':1, 'Yes':2 }
# Payment_Behaviour_map = { 'Low_Spent_Small_Value_Payments': 0 , 'Low_Spent_Medium_Value_Payments':1, 'Low_Spent_Large_Value_Payments':2,
#                          'High_Spent_Small_Value_Payments':3, 'High_Spent_Medium_Value_Payments':4, 'High_Spent_Large_Value_Payments':5
#                         }
# age_group_map = {'<18': 0, '18-25': 1, '26-35': 2, '36-50': 3, '50+': 4,}

# %% [markdown]
# ## <span style="color:Khaki;">Clusters Overview:</span>

# %% [markdown]
# <table border="3" style="width:100%; border-collapse: collapse;">
#     <tr>
#         <th style="background-color:Maroon; color:white; font-size:130%; text-align:center;"><b>Cluster 0 (Lower Risk / Better Financial Health)</b></th>
#         <th style="background-color:Maroon; color:white; font-size:130%; text-align:center;"><b>Cluster 1 (Higher Risk / Poorer Financial Health)</b></th>
#     </tr>
#     <tr>
#         <td style="width:50%;">
#         <span style="color:Khaki;font-size:110%;"><b>Credit Behavior:</b> </span>
#             <ol style="border-bottom: 1px solid #ddd; padding-bottom: 10px;">
#                 <li>Lower number of bank accounts (5) and credit cards (5)</li>
#                 <li>Fewer loans (3) and credit inquiries (4)</li>
#                 <li>Better credit mix (1 = Standard) and credit score (1 = Good)</li>
#                 <li>Lower delay from due date (14 days) and fewer delayed payments (12)</li>
#             </ol>
#             <span style="color:Khaki;font-size:110%;"><b>Income and Spending:</b></span>
#             <ol style="border-bottom: 1px solid #ddd; padding-bottom: 10px;">
#                 <li>Higher disposable income (3240.178)</li>
#                 <li>Higher annual income (13.9232 boxcox transformed)</li>
#                 <li>Higher monthly inhand salary (11.6471 boxcox transformed)</li>
#                 <li>Lower outstanding debt (30.3891 squared)</li>
#             </ol>
#             <span style="color:Khaki;font-size:110%;"><b>Financial Management:</b></span>
#             <ol style="border-bottom: 1px solid #ddd; padding-bottom: 10px;">
#                 <li>Higher savings rate (75.7477)</li>
#                 <li>Lower debt-to-income ratio (8.5042 log transformed)</li>
#                 <li>Better payment behavior (2 = Low Spent Large Value Payments)</li>
#                 <li>More likely to pay minimum amount (1 = Sometimes)</li>
#             </ol>
#         </td>
#         <td style="width:50%;">
#         <span style="color:Khaki;font-size:110%;"><b>Credit Behavior:</b></span>
#             <ol style="border-bottom: 1px solid #ddd; padding-bottom: 10px;">
#                 <li>Higher number of bank accounts (8) and credit cards (7)</li>
#                 <li>More loans (6) and credit inquiries (10)</li>
#                 <li>Poorer credit mix (0 = Poor/Bad) and credit score (0 = Poor)</li>
#                 <li>Higher delay from due date (44 days) and more delayed payments (19)</li>
#             </ol style="border-bottom: 1px solid #ddd; padding-bottom: 10px;">
#             <span style="color:Khaki;font-size:110%;"><b>Income and Spending:</b></span>
#             <ol style="border-bottom: 1px solid #ddd; padding-bottom: 10px;">
#                 <li>Lower disposable income (2148.579)</li>
#                 <li>Lower annual income (13.3624 boxcox transformed)</li>
#                 <li>Lower monthly inhand salary (10.9237 boxcox transformed)</li>
#                 <li>Higher outstanding debt (50.7106 squared)</li>
#             </ol style="border-bottom: 1px solid #ddd; padding-bottom: 10px;">
#             <span style="color:Khaki;font-size:110%;"><b>Financial Management:</b></span>
#             <ol style="border-bottom: 1px solid #ddd; padding-bottom: 10px;">
#                 <li>Lower savings rate (62.8947)</li>
#                 <li>Higher debt-to-income ratio (7.5518 log transformed)</li>
#                 <li>Poorer payment behavior (2 = Low Spent Large Value Payments, but with higher risk indicators)</li>
#                 <li>More likely to not pay minimum amount (2 = Yes, but with higher risk context)</li>
#             </ol>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## <span style="color:Khaki;">Key Insights:</span>
# <span style="color: Chartreuse;font-size:120%;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Risk Segmentation: </span>The clustering has effectively separated customers into lower-risk (Cluster 0) and higher-risk (Cluster 1) groups.
#
# <span style="color: Chartreuse;font-size:120%;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Credit Utilization: </span>Cluster 1 customers have more credit products but poorer credit scores, suggesting overextension of credit.
#
# <span style="color: Chartreuse;font-size:120%;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Payment Behavior: </span> Cluster 0 customers are more punctual with payments and have fewer delays.
#
# <span style="color: Chartreuse;font-size:120%;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Income vs. Debt: </span> Despite lower incomes, Cluster 1 customers have higher outstanding debt, indicating potential financial stress.
#
# <span style="color: Chartreuse;font-size:120%;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Financial Management: </span> Cluster 0 customers show better financial management with higher savings rates and lower debt-to-income ratios.
#
# <span style="color: Chartreuse;font-size:120%;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Credit Inquiries: </span> The higher number of credit inquiries in Cluster 1 might indicate these customers are seeking more credit, possibly due to financial difficulties.
#
# <span style="color: white;font-size:105%;"> These insights can be used to tailor financial products, adjust risk assessments, and develop targeted financial education or assistance programs for each cluster. The clear separation between clusters suggests that this segmentation could be valuable for strategic decision-making in customer relationship management and risk mitigation. </span>

# %% [markdown]
# # <span style="color:Aqua;">Training DB Scan model:</span>

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
import numpy as np

# Assuming df1[fea1] contains your data
X = df1[fea1].values

# Standard DBSCAN parameters
eps = 0.5  # You might need to adjust this value based on your data
min_samples = 5  # Minimum number of samples in a neighborhood for a point to be a core point

# %%
# Initialize DBSCAN
dbscan = DBSCAN()

# Fit DBSCAN and predict clusters
labels = dbscan.fit_predict(X)

# Calculate silhouette score, if applicable
# Silhouette score is not defined when all points are noise or there’s only one cluster
if len(set(labels)) > 1 and set(labels) != {-1}:
    score = silhouette_score(X, labels)
else:
    score = "Not applicable (no valid clusters or all points are noise)"

# Print clustering results
n_clusters = len(set(labels)) - (1 if -1 in labels else 0)  # Subtract 1 if there are noise points
n_noise = list(labels).count(-1)  # Number of noise points

print(f"Number of clusters: {n_clusters}")
print(f"Number of noise points: {n_noise}")
print(f"Silhouette score: {score}")
# Out:
# Number of clusters: 0
# Number of noise points: 1000
# Silhouette score: Not applicable (no valid clusters or all points are noise)

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
import numpy as np

# Sample data and feature set
X = df1[fea1].values

# Define DBSCAN parameters
eps = 0.5
min_samples = 5

# Apply DBSCAN
dbscan = DBSCAN()
labels = dbscan.fit_predict(X)

# Calculate silhouette score
if len(set(labels)) > 1 and set(labels) != {-1}:
    score = silhouette_score(X, labels)
else:
    score = "Not applicable (no valid clusters or all points are noise)"

# Print results
n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
n_noise = list(labels).count(-1)

print(f"Number of clusters: {n_clusters}")
print(f"Number of noise points: {n_noise}")
print(f"Silhouette score: {score}")
# Out:
# Number of clusters: 0
# Number of noise points: 1000
# Silhouette score: Not applicable (no valid clusters or all points are noise)
